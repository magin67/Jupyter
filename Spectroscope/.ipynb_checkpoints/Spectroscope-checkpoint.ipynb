# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img = mpimg.imread("Dm.png", format=None)
plt.imshow(img);
#img.shape

# %%
def extremeCoord(mVal, numPoints=5, min=True):
    CoordX, CoordY, Val = np.zeros(numPoints), np.zeros(numPoints), np.zeros(numPoints)
    for i in range(numPoints):
        if min:
            extind = np.argmin(mVal)
        else:
            extind = np.argmax(mVal)
        index = np.unravel_index(extind, mVal.shape)
        col, row = index[0], index[1]
        val = mVal[col, row]
        CoordX[i], CoordY[i], Val[i] = row, col, val
        if min:
            mVal[col, row] = 1
        else:
            mVal[col, row] = 0

    return (CoordX, CoordY, Val)

imgR = img[:, :, 0]
#imgG = img[:, :, 1]#imgB = img[:, :, 2]
rec = extremeCoord(imgR, 500, True)
plt.scatter(rec[0], rec[1], s=rec[2]*10, cmap='copper');
#print(rec[0])

# %%
#imgFig = plt.figure()
#imgAx = imgFig.add_subplot(1, 1, 1, frame_on=False)
#imgFig.subplots_adjust(top=1, bottom=0., left=0, right=1)
#imgAx.set_axis_off()
#imgAx.imshow(img);

# %%
#print(Pic)
lum_img = img[:, :, 0]
plt.imshow(lum_img) #, cmap="hot"
plt.colorbar();

# %%
plt.hist(lum_img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k');

# %%
imgplot = plt.imshow(lum_img, clim=(0.2, 0.4))
plt.colorbar();
#imgplot = plt.imshow(lum_img)
#imgplot.set_cmap('flag')

# %%
#print(img)
print(lum_img)
# Out:
# [[ 0.69803923  0.69803923  0.70588237 ...,  0.69803923  0.69803923
#    0.69803923]
#  [ 0.69803923  0.7019608   0.70588237 ...,  0.69803923  0.69803923
#    0.69803923]
#  [ 0.70588237  0.70588237  0.70980394 ...,  0.7019608   0.7019608
#    0.7019608 ]
#  ...,
#  [ 0.27058825  0.25882354  0.25098041 ...,  0.32156864  0.3137255
#    0.30980393]
#  [ 0.27450982  0.25490198  0.24313726 ...,  0.31764707  0.30980393
#    0.30588236]
#  [ 0.27843139  0.25490198  0.23921569 ...,  0.30588236  0.29803923
#    0.29803923]]
